# %% [markdown]
# <a href="https://colab.research.google.com/github/akash-bj/ML/blob/main/DT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

df = pd.DataFrame({
    'Weather': ['Sunny', 'Sunny', 'Windy', 'Rainy', 'Rainy', 'Rainy'],
    'Parents': ['Yes', 'No', 'Yes', 'Yes', 'No', 'Yes'],
    'Money': ['Rich', 'Rich', 'Rich', 'Poor', 'Rich', 'Poor'],
    'Decision': ['Cinema', 'Tennis', 'Cinema', 'Shopping', 'Shopping', 'Cinema']
})


X = pd.get_dummies(df[['Weather', 'Parents', 'Money']])


y = df['Decision']


model = DecisionTreeClassifier(criterion='entropy')
model.fit(X, y)

plt.figure(figsize=(12,6))

plot_tree(
    model,
    feature_names=X.columns,
    class_names=model.classes_,
    filled=True
)

plt.show()
