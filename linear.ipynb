# %% [markdown]
# <a href="https://colab.research.google.com/github/akash-bj/ML/blob/main/linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression


data = {
    'Weight': [37, 40, 41, 35, 25],
    'Height': [152, 142, 163, 160, 171]
}

df = pd.DataFrame(data)

X = df[['Weight']]
y = df['Height']


model = LinearRegression()
model.fit(X, y)


new_weight = [[32]]
predicted_height = model.predict(new_weight)

print("Predicted Height:", predicted_height[0])


plt.scatter(X, y, color="blue", label="Actual Data")

plt.plot(X, model.predict(X),
         color="red",
         label="Regression Line")

plt.xlabel("Weight")
plt.ylabel("Height")
plt.title("Weight vs Height")

plt.legend()
plt.show()
